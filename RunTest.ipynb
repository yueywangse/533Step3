# %%
from canvasacademicinsights.canvasmain import canvasinsights as cai
data = cai.start()
# Out:
# Welcome to the Canvas Academic Insights library, please enter some details before we can start
# Note, if the library returns a forbidden error please make a list and add the id right before the error to the list
# Enter the canvas url https://canvas.ubc.ca/
# Enter the canvas access token you created from your account 11224~vrKZcrC4WZuaXGKE6eZhZrQ8mQ97BHNYYHQnGVx6AwCFFGRhPvNM63HvXHt3UAYk
# Enter list of course ids to skip [173438, 173346, 173648, 174501, 62722]
# ID: 173263
# Done
# ID: 174003
# Done
# ID: 173637
# Done
# ID: 173914
# Done
# ID: 174035
# Done
# ID: 173332
# Done
# ID: 173638
# Done
# ID: 174247
# Done
# ID: 143370
# Done
# ID: 167247
# Done
# Finished retrieving Canvas data
# Finished retrieving Canvas data
# Enter visual or ai for summaries, or exit visual
# The following is a list of courses
# ...
