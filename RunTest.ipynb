# %%
from canvasacademicinsights.canvasmain import canvasinsights as cai
data = cai.start()
# Out:
# Welcome to the Canvas Academic Insights library, please enter some details before we can start
# Note, if the library returns a forbidden error please make a list and add the id right before the error to the list
# Enter the canvas url
# Enter the canvas access token you created from your account
# Enter list of course ids to skip
# C:\Users\yueya\miniconda3\Lib\site-packages\canvasapi\canvas.py:56: UserWarning: Canvas needs a valid URL, please provide a non-blank `base_url`.
#   warnings.warn(
# C:\Users\yueya\miniconda3\Lib\site-packages\canvasapi\canvas.py:62: UserWarning: An invalid `base_url` for the Canvas API Instance was used. Please provide a valid HTTP or HTTPS URL if possible.
#   warnings.warn(
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[1], line 2
#       1 from canvasacademicinsights.canvasmain import canvasinsights as cai
# ...
