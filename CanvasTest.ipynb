# %%
from canvasacademicinsights.canvasmain import canvasinsights as cai
data = cai.start()
# Out:
# Welcome to the Canvas Academic Insights library, please enter some details before we can start
# Note, if the library returns a forbidden error please make a list and add the id right before the error to the list
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/canvasapi/canvas.py:56: UserWarning: Canvas needs a valid URL, please provide a non-blank `base_url`.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/canvasapi/canvas.py:62: UserWarning: An invalid `base_url` for the Canvas API Instance was used. Please provide a valid HTTP or HTTPS URL if possible.
#   warnings.warn(
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[1], line 2
#       1 from canvasacademicinsights.canvasmain import canvasinsights as cai
# ----> 2 data = cai.start()
#
# ...

# %%
data

# %%
for course in data:
    courseid = course[0]
    coursename = course[1]
    courseenrollment = course[2]
    print(courseid, coursename, courseenrollment)
    gradelist = course[3]
    for item in gradelist:
        # Note that some due dates are none, dates are stored as datetime object
        if item.isAssignment():
            print('Assignment',item.name, item.score, item.total, item.date)
        elif item.isQuiz(): # can be else too
            print('Quiz',item.name, item.score, item.total, item.date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for course in data:
#       2     courseid = course[0]
#       3     coursename = course[1]
#
# TypeError: 'NoneType' object is not iterable

# %%
from canvasacademicinsights.canvasaianalyzer import grades
from canvasacademicinsights.canvasaianalyzer import organize
grades.strongCourseAsk(data)
# grades.gradesAsk(data)
# organize.dueDatesAsk(data)
# organize.studyPlanAsk(data)

# %%
from canvasacademicinsights.canvasvisualizer.canvassummaryvisualization import CanvasSummaryVisualizer

viz = CanvasSummaryVisualizer(data)
viz.plot_overall_scores()
viz.plot_grade_distribution(0)
viz.plot_missing_assignments(0)
viz.plot_num_assessments_per_course()

# %%
from canvasacademicinsights.canvasvisualizer.canvastimevisualization import CanvasTimeVisualization

time_viz = CanvasTimeVisualization(data)
time_viz.plot_item_scores(0)
time_viz.plot_all_last_graded_items_bar()
time_viz.plot_weekly_average_score_heatmap()

# %%
from canvasacademicinsights.canvasmain import canvasdataretriever as c 
from datetime import datetime
import random 

courses = []

for j in range(5): 
    gradeList = []
    sampleCourse = [
        "courseid",
        "coursename",
        "courseenrollment",
    ]
    
    counter = 1
    for i in range(10): 
        counter += 1
        if random.random() > 0.5:
            gradeList.append(c.QuizGrade(name = f"Test{random.random()}", score = random.random() * 100, total = 100, date = datetime.strptime(f"2025-11-{counter}", "%Y-%m-%d")))
        else:
            gradeList.append(c.AssignmentGrade(name = f"Test{random.random()}", score = random.random() * 100, total = 100, date = datetime.strptime(f"2025-11-{counter}", "%Y-%m-%d")))
    sampleCourse.append(gradeList)
    print(gradeList)
    courses.append(sampleCourse)

print(courses)
from canvasacademicinsights.canvasvisualizer.canvastimevisualization import CanvasTimeVisualization

time_viz = CanvasTimeVisualization(courses)
time_viz.plot_item_scores(0)
time_viz.plot_all_last_graded_items_bar()
time_viz.plot_weekly_average_score_heatmap()
